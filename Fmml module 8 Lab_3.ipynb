# %% [markdown]
# <a href="https://colab.research.google.com/github/Swaroopaaa/swaroopahackathon/blob/main/Fmml%20module%208%20Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-17 15:49:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   102MB/s    in 0.7s
#
# 2025-03-17 15:49:41 (102 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3843 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 34174  1612.03277v1  Understanding and analyzing big data is firmly...    cs
# 38175   1402.2427v1  The set of interpersonal relationships on a so...    cs
# 22564  1701.00481v2  We study the problem of estimating low-rank ma...  stat
# 7098   1710.04350v1  In building intelligent transportation systems...  stat
# 2179   1703.06103v4  Knowledge graphs enable a wide variety of appl...  stat
# ...             ...                                                ...   ...
# 30207  1711.09017v1  Learning-based methods are believed to work we...    cs
# 27039  1702.00648v2  Robust Principal Component Analysis (RPCA) aim...    cs
# 39555  1609.00278v1  The problem visual place recognition is common...    cs
# 22017   1311.4025v3  In this work we compute lower Lipschitz bounds...  stat
# 7592   1802.04376v1  Learning high quality class representations fr...    cs
#
#                                                    title  year  \
# 34174                                 Data Curation APIs  2016
# 38175  An evaluation of keyword extraction from onlin...  2014
# 22564  Stochastic Variance-reduced Gradient Descent f...  2017
# 7098   A Unified Neural Network Approach for Estimati...  2017
# 2179   Modeling Relational Data with Graph Convolutio...  2017
# ...                                                  ...   ...
# 30207  MPIIGaze: Real-World Dataset and Deep Appearan...  2017
# 27039  Side Information in Robust Principal Component...  2017
# 39555       Semantic Image Based Geolocation Given a Map  2016
# 22017       Signal Recovery from Pooling Representations  2013
# 7592   Few-Shot Learning with Metric-Agnostic Conditi...  2018
#
#                                                 keywords
# 34174  [understanding, analyzing, recognized, strateg...
# 38175  [interpersonal, relationships, community, hete...
# 22564  [estimating, measurements, nonconvex, optimiza...
# 7098   [intelligent, transportation, rideshare, predi...
# 2179   [knowledge, applications, including, answering...
# ...                                                  ...
# 30207  [unconstrained, estimation, estimation, monocu...
# 27039  [principal, component, recovering, corrupted, ...
# 39555  [recognition, localization, successful, appear...
# 22017  [lipschitz, operators, operators, rectificatio...
# 7592   [representations, approaches, accomplish, intr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 34174    [understanding, analyzing, recognized, strateg...
# 38175    [interpersonal, relationships, community, hete...
# 22564    [estimating, measurements, nonconvex, optimiza...
# 7098     [intelligent, transportation, rideshare, predi...
# 2179     [knowledge, applications, including, answering...
#                                ...
# 2391     [andersson, interpretation, particular, constr...
# 3317     [automatic, generation, information, meaningfu...
# 12905    [computational, intelligence, artificial, inte...
# 2429     [classifiers, classifiers, classifiers, introd...
# 35409    [reasoning, incomplete, knowledge, determinist...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8865 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec9f858a-a07b-4b20-afe4-56098a45d9ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec9f858a-a07b-4b20-afe4-56098a45d9ac")) {                    Plotly.newPlot(                        "ec9f858a-a07b-4b20-afe4-56098a45d9ac",                        [{"x":["organizations","interpretation","companies","increasing","discovering","calculating","classifying","recognized","researchers","locations","extracted","analyzing","particular","implement","information","abstraction","important","structured","contextualized","understanding","transforming","strategic","transform","consuming","knowledge","leveraging","unstructured","available","intelligence","developers","analytics","providing","similarity","extracting","categorizing","maintained","applications","conversation","reflected","relationship","relations","application","heterogenous","interpersonal","processing","community","characteristics","performed","relationships","characterisation","representation","assessment","investigate","assessments","evaluation","artefacts","heterogeneity","communication","extraction","experiments","algorithms","guaranteed","observations","iteration","algorithm","converges","optimization","measurements","superiority","computational","statistical","efficient","corroborate","complexity","synthetic","estimating","applicable","nonconvex","stochastic","noiseless","experience","engineering","significantly","requiring","intelligent","estimation","investigates","management","predicted","prediction","transportation","coordinate","performance","destination","generalizes","collected","convolutional","relational","characteristic","enriching","improvement","retrieval","answering","completion","introduce","demonstrate","accumulate","factorization","inference","including","demonstrating","developed","operating","specifically","effectiveness","incomplete","predicate","maintenance","realistic","classification","configuration","detection","successes","historical","decisions","approaches","prominent","underlying","parameters","efficiently","framework","directional","recognition","different","structure","transformations","bidirectional","dependency","sequences","meanwhile","collective","shrinkage","interactions","structures","optimized","pictorial","accurately","highlight","exploring","hamiltonian","benchmarks","marginalize","practical","distributions","ensembles","interventions","adversarial","generative","expressive","discriminator","posterior","likelihood","quantitative","wasserstein","candidate","resulting","supervised","formulation","discrimination","outperforming","unsupervised","generator","implicitly","interpretable","straightforward","estimates","precision","clustering","quadratic","discriminant","parameter","selection","validation","penalized","specified","simultaneously","parametric","attributes","architecture","generated","inefficient","constructed","manipulating","modalities","conditionally","personalized","optimizes","transformation","conditioned","according"],"y":[12,59,18,103,23,12,36,24,78,41,115,64,260,61,717,24,377,100,3,152,16,5,81,42,344,48,17,286,83,7,23,84,148,66,1,4,451,11,6,84,96,242,2,3,288,79,88,125,54,5,373,58,146,8,262,5,4,51,128,573,547,39,76,39,802,22,316,57,28,331,165,386,5,224,127,75,41,11,136,5,25,44,247,41,66,222,28,47,51,242,18,23,856,4,19,84,370,28,25,3,135,106,58,39,349,545,3,49,184,263,26,188,28,173,203,33,7,11,61,533,27,334,14,23,64,438,14,131,254,159,553,18,372,752,333,42,21,51,89,19,15,4,59,129,47,2,66,24,32,2,94,0,131,95,13,6,101,110,30,16,38,60,69,3,57,152,199,77,17,28,141,31,31,30,18,73,74,152,28,23,128,160,55,3,36,91,38,70,226,176,19,49,13,29,4,15,19,60,24,111],"type":"bar"},{"x":["organizations","interpretation","companies ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>of</span> <span style=''>S</span> <span style='background-color:rgba(0, 255, 0, 0.43362831858407086);'>Transform</span> <span style=''>on</span> <span style=''>Hyper</span> <span style=''>kurtosis</span> <span style=''>based</span> <span style=''>Modified</span> <span style=''>Duo</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>Histogram</span> <span style=''>Equalized</span> <span style=''>DIC</span> <span style=''>images</span> <span style=''>for</span> <span style=''>Pre</span> <span style=''>cancer</span> <span style='background-color:rgba(0, 255, 0, 0.5011235955056179);'>Detection</span> <br/><br/><span style=''>Our</span> <span style=''>proposed</span> <span style=''>hyper</span> <span style=''>kurtosis</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>histogram</span> <span style=''>equalized</span> <span style=''>DIC</span> <span style=''>images</span> <span style=''>enhances</span> <span style=''>the</span> <span style=''>contrast</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3563218390804597);'>preserving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>brightness</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>evolution</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5111111111111111);'>development</span> <span style=''>of</span> <span style=''>precancerous</span> <span style=''>activity</span> <span style=''>among</span> <span style=''>tissues</span> <span style=''>are</span> <span style=''>studied</span> <span style=''>through</span> <span style=''>S</span> <span style='background-color:rgba(0, 255, 0, 0.43362831858407086);'>transform</span> <span style=''>(ST)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3031914893617021);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.5368421052631579);'>variations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>amplitude</span> <span style=''>spectra</span> <span style=''>can</span> <span style=''>be</span> <span style=''>observed</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increased</span> <span style=''>medium</span> <span style=''>roughness</span> <span style=''>from</span> <span style=''>normal</span> <span style=''>tissue</span> <span style=''>were</span> <span style=''>observed</span> <span style=''>in</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.33962264150943394);'>frequency</span> <span style=''>domain</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomness</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>inhomogeneity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tissue</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>among</span> <span style=''>human</span> <span style=''>normal</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33688888888888896);'>different</span> <span style=''>grades</span> <span style=''>of</span> <span style=''>DIC</span> <span style=''>tissues</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.6551724137931034);'>recognized</span> <span style=''>by</span> <span style=''>ST</span> <span style=''>based</span> <span style=''>timefrequency</span> <span style=''>analysis</span> <span style=''>This</span> <span style=''>study</span> <span style=''>offers</span> <span style=''>a</span> <span style=''>simpler</span> <span style=''>and</span> <span style=''>better</span> <span style=''>way</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Policies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style=''>Sampling</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incomplete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>and</span> <span style=''>a</span> <span style=''>Cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constraint</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>infinite</span> <span style=''>horizon</span> <span style=''>average</span> <span style=''>outcome</span> <span style=''>per</span> <span style=''>period</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>that</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>average</span> <span style=''>sampling</span> <span style=''>cost</span> <span style=''>does</span> <span style=''>not</span> <span style=''>exceed</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>The</span> <span style=''>outcome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>not</span> <span style=''>known</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>adaptive</span> <span style=''>policies</span> <span style=''>under</span> <span style=''>which</span> <span style=''>the</span> <span style=''>average</span> <span style=''>outcome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>1</span> <span style=''>to</span> <span style=''>the</span> <span style=''>true</span> <span style=''>value</span> <span style=''>under</span> <span style=''>complete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>with</span> <span style=''>finite</span> <span style=''>means</span> <span style=''>We</span> <span style=''>also</span> <span style=''>compare</span> <span style=''>the</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>for</span> <span style=''>various</span> <span style=''>policies</span> <span style=''>in</span> <span style=''>this</span> <span style=''>class</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inequality</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>Sparsity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>Multitask</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <br/><br/><span style=''>From</span> <span style='background-color:rgba(255, 0, 0, 0.42105263157894723);'>concentration</span> <span style='background-color:rgba(255, 0, 0, 0.6551724137931034);'>inequalities</span> <span style=''>for</span> <span style=''>the</span> <span style=''>suprema</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>Rademacher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inequality</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>It</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>sharpen</span> <span style=''>existing</span> <span style=''>and</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>novel</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>Rademacher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexities</span> <span style=''>of</span> <span style=''>unit</span> <span style=''>balls</span> <span style=''>in</span> <span style=''>various</span> <span style=''>norms</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>appearing</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>multitask</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>or</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorization</span> <span style=''>A</span> <span style=''>key</span> <span style=''>role</span> <span style=''>is</span> <span style=''>played</span> <span style=''>by</span> <span style=''>the</span> <span style=''>largest</span> <span style='background-color:rgba(255, 0, 0, 0.6428571428571428);'>eigenvalue</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.488);'>covariance</span> <span style=''>matrix</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiscale</span> <span style=''>Residual</span> <span style=''>Mixture</span> <span style=''>of</span> <span style=''>PCA</span> <span style=''>Dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionaries</span> <span style=''>for</span> <span style=''>Optimal</span> <span style=''>Basis</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>an</span> <span style=''>over</span> <span style=''>complete</span> <span style=''>basis</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>or</span> <span style=''>inverse</span> <span style=''>problem</span> <span style=''>does</span> <span style=''>not</span> <span style=''>need</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>their</span> <span style=''>link</span> <span style=''>to</span> <span style=''>popular</span> <span style=''>already</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>sa</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Artificial</span> <span style=''>Neural</span> <span style=''>Networksk</span> <span style=''>means</span> <span style=''>or</span> <span style=''>Ojas</span> <span style=''>learning</span> <span style=''>rule</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>will</span> <span style=''>see</span> <span style=''>that</span> <span style=''>one</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorial</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>approach</span> <span style=''>The</span> <span style=''>derived</span> <span style=''>approach</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Deep</span> <span style=''>Oja</span> <span style=''>Network</span> <span style=''>We</span> <span style=''>present</span> <span style=''>results</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>tasks</span> <span style=''>and</span> <span style=''>present</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>brings</span> <span style=''>a</span> <span style=''>new</span> <span style=''>vision</span> <span style=''>on</span> <span style=''>the</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08100358422939068)
# 	automatic (0.07311827956989247)
# 	knowledge (0.12329749103942653)
# 	segmentation (0.06917562724014337)
# 	representation (0.13369175627240143)
# 	detection (0.11971326164874552)
# 	information (0.256989247311828)
# 	different (0.26953405017921145)
# 	recognition (0.13333333333333333)
# 	convolutional (0.13261648745519714)
#
# Some Statistics words are:
# 	variables (0.13532338308457711)
# 	estimation (0.17213930348258707)
# 	statistical (0.15223880597014924)
# 	theoretical (0.15323383084577114)
# 	algorithms (0.2955223880597015)
# 	algorithm (0.3970149253731343)
# 	dimensional (0.18109452736318407)
# 	distribution (0.1865671641791045)
# 	inference (0.19203980099502488)
# 	regression (0.17860696517412936)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4b15d77f-0e9e-481c-a10d-9823a66fff38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b15d77f-0e9e-481c-a10d-9823a66fff38")) {                    Plotly.newPlot(                        "4b15d77f-0e9e-481c-a10d-9823a66fff38",                        [{"x":["organizations","interpretation","companies","increasing","discovering","calculating","classifying","recognized","researchers","locations","extracted","analyzing","particular","implement","information","abstraction","important","structured","contextualized","understanding","transforming","strategic","transform","consuming","knowledge","leveraging","unstructured","available","intelligence","developers","analytics","providing","similarity","extracting","categorizing","maintained","applications","conversation","reflected","relationship","relations","application","heterogenous","interpersonal","processing","community","characteristics","performed","relationships","characterisation","representation","assessment","investigate","assessments","evaluation","artefacts","heterogeneity","communication","extraction","experiments","algorithms","guaranteed","observations","iteration","algorithm","converges","optimization","measurements","superiority","computational","statistical","efficient","corroborate","complexity","synthetic","estimating","applicable","nonconvex","stochastic","noiseless","experience","engineering","significantly","requiring","intelligent","estimation","investigates","management","predicted","prediction","transportation","coordinate","performance","destination","generalizes","collected","convolutional","relational","characteristic","enriching","improvement","retrieval","answering","completion","introduce","demonstrate","accumulate","factorization","inference","including","demonstrating","developed","operating","specifically","effectiveness","incomplete","predicate","maintenance","realistic","classification","configuration","detection","successes","historical","decisions","approaches","prominent","underlying","parameters","efficiently","framework","directional","recognition","different","structure","transformations","bidirectional","dependency","sequences","meanwhile","collective","shrinkage","interactions","structures","optimized","pictorial","accurately","highlight","exploring","hamiltonian","benchmarks","marginalize","practical","distributions","ensembles","interventions","adversarial","generative","expressive","discriminator","posterior","likelihood","quantitative","wasserstein","candidate","resulting","supervised","formulation","discrimination","outperforming","unsupervised","generator","implicitly","interpretable","straightforward","estimates","precision","clustering","quadratic","discriminant","parameter","selection","validation","penalized","specified","simultaneously","parametric","attributes","architecture","generated","inefficient","constructed","manipulating","modalities","conditionally","personalized","optimizes","transformation","conditioned","according","dependent","differentiable","extensive","generalize","invariant","arbitrary","manipulation","corresponding","descriptive","colorization","paintings","alternative","variation","experimental","motivated","preserves","variational","construct","modification","laplacian","transitions","potential","functional","multiclass","introducing","dimensional","competitive","interface","smoothness","techniques","california","proceedings","augmented","traditional","invariances","augmentation","recordings","transcription","performing","frequency","fundamental","preserving","translation","filterbank","overfitting","invariance","discussed","supervision","nonparametric","represents","probability","constraint","therefore ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	marginalize
# 	invention
# 	selections
# 	ferromagnetic
# 	degeneracy
# 	ellipsoid
# 	parametrisation
# 	impressively
# 	dendrogram
# 	pediatric
# 	physiologic
# 	transcriptional
# 	imputations
# 	misspecified
# 	diarization
# 	hermitian
# 	distributionally
# 	conservative
# 	criterions
# 	contamination
# Some words which never appear in Statistics papers:
# 	interpersonal
# 	artefacts
# 	pictorial
# 	colorization
# 	repetitions
# 	repetition
# 	differentials
# 	repetitive
# 	disambiguate
# 	exacerbates
# 	succinctly
# 	syntactic
# 	organised
# 	localisation
# 	prototypical
# 	authentication
# 	harmonics
# 	specimens
# 	hematoxylin
# 	carcinomas

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077870113881194e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
